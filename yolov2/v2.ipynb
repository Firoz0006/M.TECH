# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# Updating files:   2% (52/2055)
# Updating files:   3% (62/2055)
# Updating files:   4% (83/2055)
# Updating files:   5% (103/2055)
# Updating files:   5% (123/2055)
# Updating files:   6% (124/2055)
# Updating files:   7% (144/2055)
# Updating files:   8% (165/2055)
# Updating files:   9% (185/2055)
# Updating files:  10% (206/2055)
# Updating files:  10% (213/2055)
# Updating files:  11% (227/2055)
# Updating files:  12% (247/2055)
# Updating files:  13% (268/2055)
# Updating files:  14% (288/2055)
# Updating files:  15% (309/2055)
# Updating files:  15% (321/2055)
# Updating files:  16% (329/2055)
# Updating files:  17% (350/2055)
# Updating files:  18% (370/2055)
# Updating files:  19% (391/2055)
# Updating files:  20% (411/2055)
# Updating files:  20% (426/2055)
# Updating files:  21% (432/2055)
# Updating files:  22% (453/2055)
# Updating files:  23% (473/2055)
# Updating files:  24% (494/2055)
# Updating files:  25% (514/2055)
# ...
